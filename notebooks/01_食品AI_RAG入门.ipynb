# %% [markdown]
# # 食品AI科研问答系统 - 入门教程
#
# 这个notebook将帮助你：
# 1. 理解RAG的基本概念
# 2. 学习LlamaIndex的核心功能
# 3. 构建你的第一个食品科研问答系统

# %% [markdown]
# ## 步骤1: 导入必要的库

# %%
import os
from dotenv import load_dotenv

# 加载环境变量
load_dotenv()

# 检查API密钥
if not os.getenv('OPENAI_API_KEY'):
    print('⚠️  请在.env文件中配置OPENAI_API_KEY')
else:
    print('✅ API密钥已配置')

# %% [markdown]
# ## 步骤2: 基础的LlamaIndex使用

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.core import Settings

# 这里将加载你的食品科研文档
print('准备构建你的第一个食品科研RAG系统...')
